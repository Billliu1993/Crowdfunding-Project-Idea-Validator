# %% [markdown]
# # Kicstarter Idea Validation Tool Demo

# %%
# %run src/request.py
# Out:
# ...
# KICKSTARTER IDEA VALIDATOR RESULTS:
# ...
#
# Based on your input, the forecasted results are:
# => Predicted results: SUCCESSFUL
# => Successful probability: 59%
# ...
#
# Most similar projects on Kickstarter are identified for further comparison:
# ...
# NAME: GAME ON! TRAVEL COIN SET
# DESCRIPTION: The Game ON! Travel Coin set is elegant accessory that will enhance your gaming.
#
# STATUS: FAILED
# SIMILAR LEVEL: 64%
# DETAILED COMPARISON:
# FOR MORE DETAILS: https://www.kickstarter.com/projects/833763700/game-on-travel-coin-set
# ...
# NAME: SEVEN DEADLY SINS COIN SERIES - COIN #1 - LUST
# DESCRIPTION: The first coin in the seven deadly sins collection: Lust!
#
# STATUS: FAILED
# SIMILAR LEVEL: 62%
# DETAILED COMPARISON:
# FOR MORE DETAILS: https://www.kickstarter.com/projects/337148654/seven-deadly-sins-coin-series-coin-1-lust
# ...
# NAME: EPIC D20 COINS
# DESCRIPTION: Stunning metal D20 coins with serious heft. For adventurers everywhere.
#
# STATUS: SUCCESSFUL
# SIMILAR LEVEL: 61%
# DETAILED COMPARISON:
# ...
